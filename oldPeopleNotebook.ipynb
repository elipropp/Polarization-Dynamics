# %%
from oldPeopleSim import Distribution, generateAgents, sim, Agent
import numpy as np

# %%
# OTHER DIST OPTION
# np.random.uniform
distribution = Distribution(
    mean = 0,
    std_dev = 0.25,
    lower_bound = -1,
    upper_bound = 1,
    dist_func = np.random.normal
)
agents = generateAgents(distribution, 200)

# %%
agents = sim(agents, 100)

# %%
agents
# Out:
# {UUID('e9c073f6-8e2d-4b0e-93e1-8c7b72ece5de'): <oldPeopleSim.Agent at 0x111a61490>,
#  UUID('98c8c9f5-f5f0-45ca-9385-701bc8a87f18'): <oldPeopleSim.Agent at 0x111899d30>,
#  UUID('c98ebfaa-727e-41d2-94ce-b73eca84c169'): <oldPeopleSim.Agent at 0x108a00130>,
#  UUID('cafe3294-ba2c-4624-b467-68fea2ed1c3d'): <oldPeopleSim.Agent at 0x108a006d0>,
#  UUID('e2cef1be-0d07-4d75-a352-99f3c43ee793'): <oldPeopleSim.Agent at 0x108a00850>,
#  UUID('af1b57af-efab-4ca9-870d-626df9861d41'): <oldPeopleSim.Agent at 0x111ac1f10>,
#  UUID('9f2bff68-49a6-4501-9ec5-b5a1710be851'): <oldPeopleSim.Agent at 0x111a95cd0>,
#  UUID('0558a138-a78a-4713-8dd5-4f91a23ade0f'): <oldPeopleSim.Agent at 0x108a00730>,
#  UUID('530a6a1b-f04a-4aad-a8b4-77903cc3bcb4'): <oldPeopleSim.Agent at 0x111aa10a0>,
#  UUID('59897fcb-fdf1-4a45-b8b1-b11cbeeedeb9'): <oldPeopleSim.Agent at 0x108a00880>,
#  UUID('1b079c78-bc28-4393-b944-f408e4872011'): <oldPeopleSim.Agent at 0x111b18610>,
# ...

# %%
agents.keys()
# Out:
# dict_keys([UUID('e9c073f6-8e2d-4b0e-93e1-8c7b72ece5de'), UUID('98c8c9f5-f5f0-45ca-9385-701bc8a87f18'), UUID('c98ebfaa-727e-41d2-94ce-b73eca84c169'), UUID('cafe3294-ba2c-4624-b467-68fea2ed1c3d'), UUID('e2cef1be-0d07-4d75-a352-99f3c43ee793'), UUID('af1b57af-efab-4ca9-870d-626df9861d41'), UUID('9f2bff68-49a6-4501-9ec5-b5a1710be851'), UUID('0558a138-a78a-4713-8dd5-4f91a23ade0f'), UUID('530a6a1b-f04a-4aad-a8b4-77903cc3bcb4'), UUID('59897fcb-fdf1-4a45-b8b1-b11cbeeedeb9'), UUID('1b079c78-bc28-4393-b944-f408e4872011'), UUID('696ab144-c29f-46ed-bad2-b6365f73ac62'), UUID('a7a23cbf-4a08-4041-8b7d-83691b5face9'), UUID('99ee0cd4-5963-487e-bde2-f1ef10265ddf'), UUID('337db97c-ddc6-4f37-aec2-893a273cf031'), UUID('d500b44c-b49e-424c-9c05-32e87b6e9ecd'), UUID('78f07dbf-fbdb-48a8-a6cf-3cc79058a410'), UUID('c65e4933-b828-4e07-b960-b6eb55e8233d'), UUID('73fa182c-d174-4dc3-bd6b-3b1c28d2885f'), UUID('60093bd8-cff6-4649-8030-cb6a096ccbfa'), UUID('60d6e29a-5ca4-4738-954b-68551099e258'), UUID('69a4616e-e139-4
# ...

# %%
agents: Agent = list(agents.values())

# %%
for agent in agents:
    strat_history = agent.get_strategy_history()
    print(strat_history)
# Out:
# [<Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>]
# [<Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>, <Tolerance.MEDIUM: 1>]
# [<Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>, <Tolerance.HIGH: 2>]
# [<Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>, <Tolerance.LOW: 0>]
# ...
